# %%
#import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
#enable inline plotting
# %matplotlib inline
import numpy as np
import requests
import seaborn as sns
import matplotlib.dates as mdates

# %%
import requests
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from time import sleep

#API and date range
api_url = 'https://data.ny.gov/resource/wujg-7c2s.json'
limit = 50000
start_date = datetime(2020, 7, 1)
end_date = datetime(2024, 12, 31)

#Container for all raw data
all_data = []

#Loop through each month
current = start_date
while current <= end_date:
    start_str = current.strftime('%Y-%m-%dT00:00:00')
    end_str = (current + relativedelta(months=1) - timedelta(days=1)).strftime('%Y-%m-%dT23:59:59')
    where_clause = f"transit_timestamp between '{start_str}' and '{end_str}'"

    params = {
        '$limit': limit,
        '$where': where_clause
    }

    try:
        response = requests.get(api_url, params=params)
        response.raise_for_status()
        chunk = response.json()

        if chunk:
            all_data.extend(chunk)
            print(f" {current.strftime('%Y-%m')} — {len(chunk)} records")
        else:
            print(f"{current.strftime('%Y-%m')} — No data")

    except Exception as e:
        print(f"Error on {current.strftime('%Y-%m')}: {e}")

    current += relativedelta(months=1)
    sleep(1)  # Avoid throttling

#Convert to DataFrame
df = pd.DataFrame(all_data)
df['transit_timestamp'] = pd.to_datetime(df['transit_timestamp'], errors='coerce')
df['ridership'] = pd.to_numeric(df['ridership'], errors='coerce')

print(f"\n Finished fetching data — Total rows: {df.shape[0]}")
display(df.head())
# Out:
#  2020-07 — 50000 records
#  2020-08 — 50000 records
#  2020-09 — 50000 records
#  2020-10 — 50000 records
#  2020-11 — 50000 records
#  2020-12 — 50000 records
#  2021-01 — 50000 records
#  2021-02 — 50000 records
#  2021-03 — 50000 records
#  2021-04 — 50000 records
#  2021-05 — 50000 records
#  2021-06 — 50000 records
#  2021-07 — 50000 records
#  2021-08 — 50000 records
#  2021-09 — 50000 records
#  2021-10 — 50000 records
#  2021-11 — 50000 records
#  2021-12 — 50000 records
#  2022-01 — 50000 records
#  2022-02 — 50000 records
#  2022-03 — 50000 records
#  2022-04 — 50000 records
#  2022-05 — 50000 records
#  2022-06 — 50000 records
#  2022-07 — 50000 records
#  2022-08 — 50000 records
#  2022-09 — 50000 records
#  2022-10 — 50000 records
#  2022-11 — 50000 records
#  2022-12 — 50000 records
#  2023-01 — 50000 records
#  2023-02 — 50000 records
#  2023-03 — 50000 records
#  2023-04 — 50000 records
#  2023-05 — 50000 records
#  2023-06 — 50000 records
#  2023-07 — 50000 records
#  2023-08 — 50000 records
#  2023-09 — 50000 records
#  2023-10 — 50000 records
#  2023-11 — 50000 records
#  2023-12 — 50000 records
#  2024-01 — 50000 records
#  2024-02 — 50000 records
#  2024-03 — 50000 records
#  2024-04 — 50000 records
#  2024-05 — 50000 records
#  2024-06 — 50000 records
#  2024-07 — 50000 records
#  2024-08 — 50000 records
#  2024-09 — 50000 records
#  2024-10 — 50000 records
#  2024-11 — 50000 records
#  2024-12 — 50000 records
#
#  Finished fetching data — Total rows: 2700000
#   transit_timestamp transit_mode station_complex_id  \
# 0        2020-07-01       subway                358
# 1        2020-07-01       subway                136
# 2        2020-07-01       subway                254
# 3        2020-07-01       subway                354
# 4        2020-07-01       subway                137
#
#                  station_complex   borough payment_method  \
# 0  Newkirk Av-Little Haiti (2,5)  Brooklyn      metrocard
# 1                New Lots Av (L)  Brooklyn      metrocard
# 2             Jamaica-179 St (F)    Queens      metrocard
# 3              Sterling St (2,5)  Brooklyn      metrocard
# 4                East 105 St (L)  Brooklyn      metrocard
#
#                 fare_class_category  ridership transfers   latitude  \
# 0      Metrocard - Unlimited 30-Day        1.0       0.0   40.63997
# 1             Metrocard - Full Fare        4.0       0.0  40.658733
# 2             Metrocard - Full Fare        1.0       1.0  40.712646
# 3  Metrocard - Seniors & Disability        1.0       0.0  40.662743
# 4      Metrocard - Unlimited 30-Day        1.0       0.0  40.650574
#
#    longitude                                       georeference
# 0  -73.94841  {'type': 'Point', 'coordinates': [-73.94841, 4...
# 1  -73.89923  {'type': 'Point', 'coordinates': [-73.89923, 4...
# 2  -73.78381  {'type': 'Point', 'coordinates': [-73.78381, 4...
# 3  -73.95085  {'type': 'Point', 'coordinates': [-73.95085, 4...
# 4  -73.89948  {'type': 'Point', 'coordinates': [-73.89948, 4...

# %%
#save data from the api request into a csv file
df.to_csv('nyc_ridership_raw.csv', index=False)

# %%
#read the csv file for further data manipulation
df_data=pd.read_csv('nyc_ridership_raw.csv')
#display(df_data) #check output

# %%
#create a copy of the original dataframe to work on
#to preserve the original just in case
df2=df_data.copy()
#display the data
display(df2.head(20))
# Out:
#       transit_timestamp transit_mode station_complex_id  \
# 0   2020-07-01 00:00:00       subway                358
# 1   2020-07-01 00:00:00       subway                136
# 2   2020-07-01 00:00:00       subway                254
# 3   2020-07-01 00:00:00       subway                354
# 4   2020-07-01 00:00:00       subway                137
# 5   2020-07-01 00:00:00       subway                136
# 6   2020-07-01 00:00:00       subway                246
# 7   2020-07-01 00:00:00       subway                 45
# 8   2020-07-01 00:00:00       subway                138
# 9   2020-07-01 00:00:00       subway                352
# 10  2020-07-01 00:00:00       subway                453
# 11  2020-07-01 00:00:00       subway                134
# 12  2020-07-01 00:00:00       subway                213
# 13  2020-07-01 00:00:00       subway                356
# 14  2020-07-01 00:00:00       subway                137
# 15  2020-07-01 00:00:00       subway                137
# 16  2020-07-01 00:00:00       subway                 14
# 17  2020-07-01 00:00:00       subway                256
# 18  2020-07-01 00:00:00       subway                135
# 19  2020-07-01 00:00:00       subway                 13
#
#                   station_complex    borough payment_method  \
# 0   Newkirk Av-Little Haiti (2,5)   Brooklyn      metrocard
# 1                 New Lots Av (L)   Brooklyn      metrocard
# 2              Jamaica-179 St (F)     Queens      metrocard
# 3               Sterling St (2,5)   Brooklyn      metrocard
# 4                 East 105 St (L)   Brooklyn      metrocard
# 5                 New Lots Av (L)   Brooklyn      metrocard
# 6                    Avenue I (F)   Brooklyn      metrocard
# 7                 Beverley Rd (Q)   Brooklyn      metrocard
# 8      Canarsie-Rockaway Pkwy (L)   Brooklyn      metrocard
# 9                 New Lots Av (3)   Brooklyn      metrocard
# 10          82 St-Jackson Hts (7)     Queens      metrocard
# 11                  Sutter Av (L)   Brooklyn      metrocard
# 12               Fordham Rd (B,D)      Bronx           omny
# 13                Church Av (2,5)   Brooklyn      metrocard
# 14                East 105 St (L)   Brooklyn      metrocard
# 15                East 105 St (L)   Brooklyn      metrocard
# 16                    23 St (R,W)  Manhattan      metrocard
# 17               Parsons Blvd (F)     Queens      metrocard
# 18                 Livonia Av (L)   Brooklyn      metrocard
# 19                    28 St (R,W)  Manhattan      metrocard
#
#                  fare_class_category  ridership  transfers   latitude  \
# 0       Metrocard - Unlimited 30-Day        1.0        0.0  40.639970
# 1              Metrocard - Full Fare        4.0        0.0  40.658733
# 2              Metrocard - Full Fare        1.0        1.0  40.712646
# 3   Metrocard - Seniors & Disability        1.0        0.0  40.662743
# 4       Metrocard - Unlimited 30-Day        1.0        0.0  40.650574
# 5        Metrocard - Unlimited 7-Day        2.0        0.0  40.658733
# 6              Metrocard - Full Fare        3.0        0.0  40.625320
# 7              Metrocard - Full Fare        2.0        0.0  40.644030
# 8                  Metrocard - Other        1.0        0.0  40.646652
# 9                  Metrocard - Other        7.0        0.0  40.666237
# 10                 Metrocard - Other        7.0        0.0  40.747658
# 11             Metrocard - Full Fare        3.0        0.0  40.669370
# 12                  OMNY - Full Fare        1.0        0.0  40.861298
# 13                 Metrocard - Other        2.0        0.0  40.650845
# 14             Metrocard - Full Fare        2.0        0.0  40.650574
# 15       Metrocard - Unlimited 7-Day        2.0        0.0  40.650574
# 16       Metrocard - Unlimited 7-Day        2.0        0.0  40.741302
# 17             Metrocard - Full Fare        2.0        0.0  40.707565
# 18       Metrocard - Unlimited 7-Day        2.0        0.0  40.664040
# 19      Metrocard - Unlimited 30-Day        1.0        0.0  40.745495
#
#     longitude                                       georeference
# 0   -73.94841  {'type': 'Point', 'coordinates': [-73.94841, 4...
# 1   -73.89923  {'type': 'Point', 'coordinates': [-73.89923, 4...
# 2   -73.78381  {'type': 'Point', 'coordinates': [-73.78381, 4...
# 3   -73.95085  {'type': 'Point', 'coordinates': [-73.95085, 4...
# 4   -73.89948  {'type': 'Point', 'coordinates': [-73.89948, 4...
# 5   -73.89923  {'type': 'Point', 'coordinates': [-73.89923, 4...
# 6   -73.97613  {'type': 'Point', 'coordinates': [-73.97613, 4...
# 7   -73.96449  {'type': 'Point', 'coordinates': [-73.96449, 4...
# 8   -73.90185  {'type': 'Point', 'coordinates': [-73.90185, 4...
# 9   -73.88408  {'type': 'Point', 'coordinates': [-73.88408, 4...
# 10  -73.88370  {'type': 'Point', 'coordinates': [-73.8837, 40...
# 11  -73.90198  {'type': 'Point', 'coordinates': [-73.90198, 4...
# 12  -73.89775  {'type': 'Point', 'coordinates': [-73.89775, 4...
# 13  -73.94958  {'type': 'Point', 'coordinates': [-73.94958, 4...
# 14  -73.89948  {'type': 'Point', 'coordinates': [-73.89948, 4...
# 15  -73.89948  {'type': 'Point', 'coordinates': [-73.89948, 4...
# 16  -73.98934  {'type': 'Point', 'coordinates': [-73.98934, 4...
# 17  -73.80333  {'type': 'Point', 'coordinates': [-73.80333, 4...
# 18  -73.90057  {'type': 'Point', 'coordinates': [-73.90057, 4...
# 19  -73.98869  {'type': 'Point', 'coordinates': [-73.98869, 4...

# %%
df2.isnull().sum() #make sure there are no null values
# Out:
# transit_timestamp      0
# transit_mode           0
# station_complex_id     0
# station_complex        0
# borough                0
# payment_method         0
# fare_class_category    0
# ridership              0
# transfers              0
# latitude               0
# longitude              0
# georeference           0
# dtype: int64

# %%
#drop unnecessary columns
df2.drop(['georeference'], axis=1, inplace=True)
#print(df2)
#df.rename(columns={'state':'registration_state'}, inplace=True) #rename ambiguous columns
df2.dropna(inplace=True) #drop rows with null values
display(df2)
# Out:
#            transit_timestamp transit_mode station_complex_id  \
# 0        2020-07-01 00:00:00       subway                358
# 1        2020-07-01 00:00:00       subway                136
# 2        2020-07-01 00:00:00       subway                254
# 3        2020-07-01 00:00:00       subway                354
# 4        2020-07-01 00:00:00       subway                137
# ...                      ...          ...                ...
# 2699995  2024-12-01 16:00:00       subway                312
# 2699996  2024-12-01 16:00:00       subway                312
# 2699997  2024-12-01 16:00:00       subway                313
# 2699998  2024-12-01 16:00:00       subway                313
# 2699999  2024-12-01 16:00:00       subway                313
#
#                        station_complex    borough payment_method  \
# 0        Newkirk Av-Little Haiti (2,5)   Brooklyn      metrocard
# 1                      New Lots Av (L)   Brooklyn      metrocard
# 2                   Jamaica-179 St (F)     Queens      metrocard
# 3                    Sterling St (2,5)   Brooklyn      metrocard
# 4                      East 105 St (L)   Brooklyn      metrocard
# ...                                ...        ...            ...
# 2699995                      79 St (1)  Manhattan      metrocard
# 2699996                      79 St (1)  Manhattan           omny
# 2699997                  72 St (1,2,3)  Manhattan      metrocard
# 2699998                  72 St (1,2,3)  Manhattan           omny
# 2699999                  72 St (1,2,3)  Manhattan           omny
#
#                       fare_class_category  ridership  transfers   latitude  \
# 0            Metrocard - Unlimited 30-Day        1.0        0.0  40.639970
# 1                   Metrocard - Full Fare        4.0        0.0  40.658733
# 2                   Metrocard - Full Fare        1.0        1.0  40.712646
# 3        Metrocard - Seniors & Disability        1.0        0.0  40.662743
# 4            Metrocard - Unlimited 30-Day        1.0        0.0  40.650574
# ...                                   ...        ...        ...        ...
# 2699995  Metrocard - Seniors & Disability       16.0        3.0  40.783936
# 2699996                   OMNY - Students       28.0        4.0  40.783936
# 2699997      Metrocard - Unlimited 30-Day      119.0        0.0  40.778454
# 2699998                      OMNY - Other        2.0        0.0  40.778454
# 2699999                   OMNY - Students       56.0        0.0  40.778454
#
#          longitude
# 0        -73.94841
# 1        -73.89923
# 2        -73.78381
# 3        -73.95085
# 4        -73.89948
# ...            ...
# 2699995  -73.97992
# 2699996  -73.97992
# 2699997  -73.98197
# 2699998  -73.98197
# 2699999  -73.98197
#
# [2700000 rows x 11 columns]

# %%
null_summary = df2.isna().sum()
print(null_summary)
# Out:
# transit_timestamp      0
# transit_mode           0
# station_complex_id     0
# station_complex        0
# borough                0
# payment_method         0
# fare_class_category    0
# ridership              0
# transfers              0
# latitude               0
# longitude              0
# dtype: int64

# %%
#customize palette and style
sns.set_style('darkgrid')
sns.set_palette("Set2")

# %%
print(df2.dtypes)
# Out:
# transit_timestamp       object
# transit_mode            object
# station_complex_id      object
# station_complex         object
# borough                 object
# payment_method          object
# fare_class_category     object
# ridership              float64
# transfers              float64
# latitude               float64
# longitude              float64
# dtype: object

# %%
df2['transit_timestamp'] = pd.to_datetime(df2['transit_timestamp'], errors='coerce')

# %%
df2['ridership'] = pd.to_numeric(df2['ridership'], errors='coerce')
df2['transfers'] = pd.to_numeric(df2['transfers'], errors='coerce')
df2['latitude'] = pd.to_numeric(df2['latitude'], errors='coerce')
df2['longitude'] = pd.to_numeric(df2['longitude'], errors='coerce')

# %%
for col in ['transit_mode', 'borough', 'payment_method', 'fare_class_category']:
    df2[col] = df2[col].astype('category')

# %%
print(df2.dtypes)
# Out:
# transit_timestamp      datetime64[ns]
# transit_mode                 category
# station_complex_id             object
# station_complex                object
# borough                      category
# payment_method               category
# fare_class_category          category
# ridership                     float64
# transfers                     float64
# latitude                      float64
# longitude                     float64
# dtype: object

# %%
df2.head(10)
# Out:
#   transit_timestamp transit_mode station_complex_id  \
# 0        2020-07-01       subway                358
# 1        2020-07-01       subway                136
# 2        2020-07-01       subway                254
# 3        2020-07-01       subway                354
# 4        2020-07-01       subway                137
# 5        2020-07-01       subway                136
# 6        2020-07-01       subway                246
# 7        2020-07-01       subway                 45
# 8        2020-07-01       subway                138
# 9        2020-07-01       subway                352
#
#                  station_complex   borough payment_method  \
# 0  Newkirk Av-Little Haiti (2,5)  Brooklyn      metrocard
# 1                New Lots Av (L)  Brooklyn      metrocard
# 2             Jamaica-179 St (F)    Queens      metrocard
# 3              Sterling St (2,5)  Brooklyn      metrocard
# 4                East 105 St (L)  Brooklyn      metrocard
# 5                New Lots Av (L)  Brooklyn      metrocard
# 6                   Avenue I (F)  Brooklyn      metrocard
# 7                Beverley Rd (Q)  Brooklyn      metrocard
# 8     Canarsie-Rockaway Pkwy (L)  Brooklyn      metrocard
# 9                New Lots Av (3)  Brooklyn      metrocard
#
#                 fare_class_category  ridership  transfers   latitude  \
# 0      Metrocard - Unlimited 30-Day        1.0        0.0  40.639970
# 1             Metrocard - Full Fare        4.0        0.0  40.658733
# 2             Metrocard - Full Fare        1.0        1.0  40.712646
# 3  Metrocard - Seniors & Disability        1.0        0.0  40.662743
# 4      Metrocard - Unlimited 30-Day        1.0        0.0  40.650574
# 5       Metrocard - Unlimited 7-Day        2.0        0.0  40.658733
# 6             Metrocard - Full Fare        3.0        0.0  40.625320
# 7             Metrocard - Full Fare        2.0        0.0  40.644030
# 8                 Metrocard - Other        1.0        0.0  40.646652
# 9                 Metrocard - Other        7.0        0.0  40.666237
#
#    longitude
# 0  -73.94841
# 1  -73.89923
# 2  -73.78381
# 3  -73.95085
# 4  -73.89948
# 5  -73.89923
# 6  -73.97613
# 7  -73.96449
# 8  -73.90185
# 9  -73.88408

# %% [markdown]
# Total Ridership by Payment Method

# %%
# Convert to datetime and extract year
df2['transit_timestamp'] = pd.to_datetime(df2['transit_timestamp'])
df2['year'] = df2['transit_timestamp'].dt.year

# Group by year and payment method
yearly_methods = df2.groupby(['year', 'payment_method'])['ridership'].sum().reset_index()

# Pivot to compare side by side
yearly_pivot = yearly_methods.pivot(index='year', columns='payment_method', values='ridership').fillna(0).astype(int)

# Print table
print("Yearly Ridership by Payment Method:\n")
print(yearly_pivot)
# Out:
# Yearly Ridership by Payment Method:
#
# payment_method  metrocard      omny
# year
# 2020              6867230    536500
# 2021             15709643   3709910
# 2022             16815194   7907873
# 2023             14720009  10991871
# 2024             11123266  12786358
# <ipython-input-16-4fa24ccacdb0>:6: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   yearly_methods = df2.groupby(['year', 'payment_method'])['ridership'].sum().reset_index()

# %%
# Plot stacked bar chart
yearly_pivot.plot(kind='bar', stacked=True, figsize=(12, 6))

plt.title("Total Ridership by Payment Method (Yearly)")
plt.xlabel("Year")
plt.ylabel("Total Ridership")
plt.legend(title="Payment Method")
plt.tight_layout()
plt.grid(axis='y')
plt.show()

# %%
colors = ['orange', 'black'] #orange for metrocard and black for Omny

yearly_pivot.plot(kind='bar', stacked=True, figsize=(12, 6), color=colors)

plt.title("Total Ridership by Payment Method (Yearly)")
plt.xlabel("Year")
plt.ylabel("Total Ridership")
plt.legend(title="Payment Method", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.grid(axis='y')
plt.show()

# %%
df2.head(10)
# Out:
#   transit_timestamp transit_mode station_complex_id  \
# 0        2020-07-01       subway                358
# 1        2020-07-01       subway                136
# 2        2020-07-01       subway                254
# 3        2020-07-01       subway                354
# 4        2020-07-01       subway                137
# 5        2020-07-01       subway                136
# 6        2020-07-01       subway                246
# 7        2020-07-01       subway                 45
# 8        2020-07-01       subway                138
# 9        2020-07-01       subway                352
#
#                  station_complex   borough payment_method  \
# 0  Newkirk Av-Little Haiti (2,5)  Brooklyn      metrocard
# 1                New Lots Av (L)  Brooklyn      metrocard
# 2             Jamaica-179 St (F)    Queens      metrocard
# 3              Sterling St (2,5)  Brooklyn      metrocard
# 4                East 105 St (L)  Brooklyn      metrocard
# 5                New Lots Av (L)  Brooklyn      metrocard
# 6                   Avenue I (F)  Brooklyn      metrocard
# 7                Beverley Rd (Q)  Brooklyn      metrocard
# 8     Canarsie-Rockaway Pkwy (L)  Brooklyn      metrocard
# 9                New Lots Av (3)  Brooklyn      metrocard
#
#                 fare_class_category  ridership  transfers   latitude  \
# 0      Metrocard - Unlimited 30-Day        1.0        0.0  40.639970
# 1             Metrocard - Full Fare        4.0        0.0  40.658733
# 2             Metrocard - Full Fare        1.0        1.0  40.712646
# 3  Metrocard - Seniors & Disability        1.0        0.0  40.662743
# 4      Metrocard - Unlimited 30-Day        1.0        0.0  40.650574
# 5       Metrocard - Unlimited 7-Day        2.0        0.0  40.658733
# 6             Metrocard - Full Fare        3.0        0.0  40.625320
# 7             Metrocard - Full Fare        2.0        0.0  40.644030
# 8                 Metrocard - Other        1.0        0.0  40.646652
# 9                 Metrocard - Other        7.0        0.0  40.666237
#
#    longitude  year
# 0  -73.94841  2020
# 1  -73.89923  2020
# 2  -73.78381  2020
# 3  -73.95085  2020
# 4  -73.89948  2020
# 5  -73.89923  2020
# 6  -73.97613  2020
# 7  -73.96449  2020
# 8  -73.90185  2020
# 9  -73.88408  2020

# %% [markdown]
# What is the distribution of fare class categories?

# %%
# Group by fare_class_category and payment_method
fare_dist = df2.groupby(['fare_class_category', 'payment_method'])['ridership'].sum().reset_index()

# Examine the aggregated fare distribution
print(fare_dist.head())
# Out:
#      fare_class_category payment_method   ridership
# 0  Metrocard - Fair Fare      metrocard   3387927.0
# 1  Metrocard - Fair Fare           omny         0.0
# 2  Metrocard - Full Fare      metrocard  26211292.0
# 3  Metrocard - Full Fare           omny         0.0
# 4      Metrocard - Other      metrocard   4959505.0
# <ipython-input-19-4850f700fdb7>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fare_dist = df2.groupby(['fare_class_category', 'payment_method'])['ridership'].sum().reset_index()

# %%
fare_dist['percentage'] = fare_dist.groupby('payment_method')['ridership'].transform(lambda x: 100 * x / x.sum())
print(fare_dist)
# Out:
#                  fare_class_category payment_method   ridership  percentage
# 0              Metrocard - Fair Fare      metrocard   3387927.0    5.193392
# 1              Metrocard - Fair Fare           omny         0.0    0.000000
# 2              Metrocard - Full Fare      metrocard  26211292.0   40.179589
# 3              Metrocard - Full Fare           omny         0.0    0.000000
# 4                  Metrocard - Other      metrocard   4959505.0    7.602482
# 5                  Metrocard - Other           omny         0.0    0.000000
# 6   Metrocard - Seniors & Disability      metrocard   4079020.0    6.252776
# 7   Metrocard - Seniors & Disability           omny         0.0    0.000000
# 8               Metrocard - Students      metrocard   3984998.0    6.108649
# 9               Metrocard - Students           omny         0.0    0.000000
# 10      Metrocard - Unlimited 30-Day      metrocard  10773171.0   16.514317
# 11      Metrocard - Unlimited 30-Day           omny         0.0    0.000000
# 12       Metrocard - Unlimited 7-Day      metrocard  11839429.0   18.148796
# 13       Metrocard - Unlimited 7-Day           omny         0.0    0.000000
# 14                  OMNY - Fair Fare      metrocard         0.0    0.000000
# 15                  OMNY - Fair Fare           omny        60.0    0.000167
# 16                  OMNY - Full Fare      metrocard         0.0    0.000000
# 17                  OMNY - Full Fare           omny  35377511.0   98.455435
# 18                      OMNY - Other      metrocard         0.0    0.000000
# 19                      OMNY - Other           omny     54395.0    0.151381
# 20       OMNY - Seniors & Disability      metrocard         0.0    0.000000
# 21       OMNY - Seniors & Disability           omny    140564.0    0.391189
# 22                   OMNY - Students      metrocard         0.0    0.000000
# 23                   OMNY - Students           omny    359982.0    1.001828
# <ipython-input-20-ff6bcd63015b>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fare_dist['percentage'] = fare_dist.groupby('payment_method')['ridership'].transform(lambda x: 100 * x / x.sum())

# %%
import seaborn as sns

plt.figure(figsize=(12,6))
sns.barplot(data=fare_dist, x='fare_class_category', y='percentage', hue='payment_method')
plt.title("Fare Class Category Distribution by Payment Method")
plt.xlabel("Fare Class Category")
plt.ylabel("Percentage of Total Ridership")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
#  How does fare class usage vary by borough?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Group and count fare class usage by borough
fare_by_borough = df2.groupby(['borough', 'fare_class_category'])['ridership'].sum().reset_index()

# Plot
plt.figure(figsize=(12, 6))
sns.barplot(data=fare_by_borough, x='borough', y='ridership', hue='fare_class_category')
plt.title('Fare Class Usage by Borough')
plt.ylabel('Total Ridership')
plt.xticks(rotation=45)
plt.legend(title='Fare Class')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-45-8b48ad3ec468>:5: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   fare_by_borough = df2.groupby(['borough', 'fare_class_category'])['ridership'].sum().reset_index()

# %%
# Save key dataframes as CSV
yearly_pivot.to_csv("yearly_ridership_by_payment_method.csv")
#monthly_usage.to_csv("monthly_usage.csv", index=False)
fare_dist.to_csv("fare_distribution.csv", index=False)
fare_by_borough.to_csv("fare_by_borough.csv", index=False)

# %%
# Convert pivoted to long format

# Load your original CSV
df3 = pd.read_csv("/content/yearly_ridership_by_payment_method.csv")

# Convert from wide to long format
df3_long = df3.melt(
    id_vars="year",                # Column to keep fixed
    var_name="payment_method",     # New column name for previous column headers
    value_name="ridership"         # New column name for values
)

# Save or view the result
df3_long.to_csv("yearly_ridership_by_payment_method_long.csv", index=False)
print(df3_long.head())
# Out:
#    year payment_method  ridership
# 0  2020      metrocard    6867230
# 1  2021      metrocard   15709643
# 2  2022      metrocard   16815194
# 3  2023      metrocard   14720009
# 4  2024      metrocard   11123266

# %%
import pandas as pd

# Load CSV files
yearly_long_clean = pd.read_csv("yearly_ridership_by_payment_method_long.csv")
fare_dist = pd.read_csv("fare_distribution.csv")
fare_by_borough = pd.read_csv("fare_by_borough.csv")

# Check available columns for safe merging
print("Yearly long columns:", yearly_long_clean.columns)
print("Fare distribution columns:", fare_dist.columns)
print("Fare by borough columns:", fare_by_borough.columns)

# Merge datasets
df4 = yearly_long_clean.merge(fare_dist, on="payment_method", how="left")
df4 = df4.merge(fare_by_borough, on="fare_class_category", how="left")

# Save the final combined table
df4.to_csv("/content/sample_data/combined_tableau_ready.csv", index=False)

print(" Combined file saved as combined_tableau_ready.csv")
print(df4.head())
# Out:
# Yearly long columns: Index(['year', 'payment_method', 'ridership'], dtype='object')
# Fare distribution columns: Index(['fare_class_category', 'payment_method', 'ridership', 'percentage'], dtype='object')
# Fare by borough columns: Index(['borough', 'fare_class_category', 'ridership'], dtype='object')
#  Combined file saved as combined_tableau_ready.csv
#    year payment_method  ridership_x    fare_class_category  ridership_y  \
# 0  2020      metrocard      6867230  Metrocard - Fair Fare    3387927.0
# 1  2020      metrocard      6867230  Metrocard - Fair Fare    3387927.0
# 2  2020      metrocard      6867230  Metrocard - Fair Fare    3387927.0
# 3  2020      metrocard      6867230  Metrocard - Fair Fare    3387927.0
# 4  2020      metrocard      6867230  Metrocard - Fair Fare    3387927.0
#
#    percentage        borough  ridership
# 0    5.193392          Bronx   595532.0
# 1    5.193392       Brooklyn   986840.0
# 2    5.193392      Manhattan  1270311.0
# 3    5.193392         Queens   529518.0
# 4    5.193392  Staten Island     5726.0
